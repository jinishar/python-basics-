# %%
#create table
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(type(lst))
tpl=tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers=tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuples=(1,"hello world",3.14,True)
print(mixed_tuples)
# Out:
# (1, 'hello world', 3.14, True)

# %%
## accessing tuple elements

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(numbers[2])
print(numbers[-1])
print(numbers[0:4])
print(numbers[::-1])
# Out:
# 3
# 6
# (1, 2, 3, 4)
# (6, 5, 4, 3, 2, 1)

# %%
##tuple operations

concatenation = numbers + mixed_tuples
print(concatenation)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'hello world', 3.14, True)

# %%
mixed_tuples * 3
# Out:
# (1,
#  'hello world',
#  3.14,
#  True,
#  1,
#  'hello world',
#  3.14,
#  True,
#  1,
#  'hello world',
#  3.14,
#  True)

# %%
numbers*3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## immutatble nature of tuples, immutable

lst=[1,2,3,4,5]
print(lst)

lst[1]='jenny'
print(lst)

##numbers[1]='jenny'
# Out:
# [1, 2, 3, 4, 5]
# [1, 'jenny', 3, 4, 5]

# %%
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#tuple methods
print(numbers.count(1))
print(numbers.index(3)) #element 3 is present in the tuple
# Out:
# 1
# 2

# %%
##packing and unpacking tuple
packed_tuple=1,'hello',3.14
print(packed_tuple)
# Out:
# (1, 'hello', 3.14)

# %%
#unpacking
a,b,c=packed_tuple

print(a)
print(b)
print(c)
# Out:
# 1
# hello
# 3.14

# %%
##unpacking w *
numbers=(1,2,3,4,5)
first,*middle, last = numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4]
# 5

# %%
lst=[[1,2,3,4],[5,6,7,8],[1,'hellow world',3.14,'c']]
lst[2][0:3]
# Out:
# [1, 'hellow world', 3.14]

# %%
lst=[[1,2,3,4],[5,6,7,8],(1,'hellow world',3.14,'c')] ##tuple inside a list
lst[2][0:2]
# Out:
# (1, 'hellow world')

# %%
nested_tuple =  ((1,2,3),('a','b','c'),(True,False))

print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end=" ")
    print()
# Out:
# 1 2 3
# a b c
# True False
